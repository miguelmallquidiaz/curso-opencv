# %% [markdown]
# # Instalación de paquetes

# %%
# %pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# %pip install numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Datos temporales se almacenan en el RAM.

# %%
a = 11
b = 12
c = a + b
print(c)

# python esta guardando las variables y no las acciones por eso me vota 23 a pesar de cambiar el valor
b = 120
print(c)
# Out:
# 23
# 23

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# leer una imagen
# Se utiliza r para indicarle que es una cadena y que no interpreta las secuencias especiales como el doble salto (\n)
image = cv2.imread(r'C:\Users\HP\Documents\curso-opencv\assets\00012908_000.jpg')

# Convertirlo de BGR a RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Convertir la tupla en un array
image = np.array(image)
image.shape
# Out:
# (1024, 1024, 3)

# %%
plt.imshow(image)

# %% [markdown]
# Cada pixel tiene un númerito y es conformado como si fuera una matriz

# %% [markdown]
# RGB
# <br>R(Rojo) posición 0
# <br>G(Verde) posición 1
# <br>B(Azul) posición 2

# %%
plt.imshow(image[:,:,0])

# %%
plt.imshow(image[:,:,1])

# %%
plt.imshow(image[:,:,2])

# %% [markdown]
# Gráfica de escaner de un cáncer en el pulmón

# %%
image2 = cv2.imread(r'C:\Users\HP\Documents\curso-opencv\assets\00013012024_000.jpeg')
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image2)

# %%
plt.imshow(image2[:,:, 0])

# %%
plt.imshow(image2[:,:, 1])

# %%
plt.imshow(image2[:,:, 2])
